# %%
import pyautogui as auto
from time import sleep
import pandas as pd
import numpy as np
import pyperclip as clip
import requests
#from bs4 import BeautifulSoup

# %%
pip install tk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_excel("Useful.xlsx")
df2=df.copy()

# %%
file=open("Bash.txt",'a')

# %%
faltu2=open("Faltu.txt",'a')
#faltu2.close()

# %%
ulla=np.round_(np.array(df['upper_left_latitude']),decimals=2)
ullo=np.round_(np.array(df['upper_left_longitude']),decimals=2)
urla=np.round_(np.array(df['upper_right_latitude']),decimals=2)
urlo=np.round_(np.array(df['upper_right_longitude']),decimals=2)
brla=np.round_(np.array(df['lower_right_latitude']),decimals=2)
brlo=np.round_(np.array(df['lower_right_longitude']),decimals=2)
blla=np.round_(np.array(df['lower_left_latitude']),decimals=2)
bllo=np.round_(np.array(df['lower_left_longitude']),decimals=2)
name=np.array(df['Filename'])
#lis=[]
#for i in name:
#    lis.append(i[12:20])
#name=np.array(lis)
#len(name)
df['Filename']=name

# %%
ulla2=ulla
ullo2=ullo
urla2=urla
urlo2=urlo
brla2=brla
brlo2=brlo
blla2=blla
bllo2=bllo

# %%
min_lat,max_lat,min_long,max_long=[],[],[],[]
for i in range(len(ulla)):
    min_lat.append(min(ulla[i],urla[i],blla[i],brla[i]))
    max_lat.append(max(ulla[i],urla[i],blla[i],brla[i]))
    min_long.append(min(ullo[i],urlo[i],bllo[i],brlo[i]))
    max_long.append(max(ullo[i],urlo[i],bllo[i],brlo[i]))

# %%
df['max_lat']=max_lat
df['min_lat']=min_lat
df['max_long']=max_long
df['min_long']=min_long
df=df[df['max_lat']<42]
df=df[df['min_lat']>-42]
df=df[df['min_long']>-45]
df=df[df['max_long']<45]
df
# Out:
#      S. No.                                       Filename  \
# 23       24  ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip
# 34       35  ch2_tmc_ndn_20200702T1355037620_d_dtm_d18.zip
# 81       82  ch2_tmc_ndn_20211230T0550281888_d_oth_d18.zip
# 88       89  ch2_tmc_ndn_20200608T1622389722_d_oth_d18.zip
# 113     114  ch2_tmc_ndn_20191201T0311138983_d_oth_d18.zip
# 126     127  ch2_tmc_ndn_20200609T1600218929_d_oth_d18.zip
# 171     172  ch2_tmc_ndn_20191229T0015253876_d_dtm_d18.zip
# 177     178  ch2_tmc_ndn_20211226T2103295074_d_dtm_d18.zip
# 210     211  ch2_tmc_ndn_20220716T2034569261_d_oth_d18.zip
# 232     233  ch2_tmc_ndn_20200708T2320352233_d_oth_d18.zip
# 241     242  ch2_tmc_ndn_20211225T1935192015_d_oth_d18.zip
# 349     350  ch2_tmc_ndn_20220718T0231336107_d_dtm_d18.zip
# 350     351  ch2_tmc_ndn_20220527T0134064246_d_dtm_d18.zip
# 351     352  ch2_tmc_ndn_20200717T0442596796_d_oth_d18.zip
# 392     393  ch2_tmc_ndn_20200607T2239162106_d_oth_d18.zip
# ...

# %%
ulla=np.round_(np.array(df['upper_left_latitude']),decimals=2)
ullo=np.round_(np.array(df['upper_left_longitude']),decimals=2)
urla=np.round_(np.array(df['upper_right_latitude']),decimals=2)
urlo=np.round_(np.array(df['upper_right_longitude']),decimals=2)
brla=np.round_(np.array(df['lower_right_latitude']),decimals=2)
brlo=np.round_(np.array(df['lower_right_longitude']),decimals=2)
blla=np.round_(np.array(df['lower_left_latitude']),decimals=2)
bllo=np.round_(np.array(df['lower_left_longitude']),decimals=2)
name=np.array(df['Filename'])

# %%
lis=[]
for i in ullo:
    if i<0:
        lis.append(i+360)
    else:
        lis.append(i)
ullo=np.array(lis)
lis=[]
for i in urlo:
    if i<0:
        lis.append(i+360)
    else:
        lis.append(i)
urlo=np.array(lis)
lis=[]
for i in brlo:
    if i<0:
        lis.append(i+360)
    else:
        lis.append(i)
brlo=np.array(lis)
lis=[]
for i in bllo:
    if i<0:
        lis.append(i+360)
    else:
        lis.append(i)
bllo=np.array(lis)

# %%
df['upper_left_longitude']=ullo
df['upper_right_longitude']=urlo
df['lower_left_longitude']=bllo
df['lower_right_longitude']=brlo
df['upper_left_latitude']=ulla

# %%
nac_files=['M1218788292RE.IMG', 'M132651706LE.IMG', 'M157886507LE.IMG', 'M1218795212LE.IMG', 'M132651706RE.IMG', 'M157886507RE.IMG', 'M1218795212RE.IMG', 'M132658466LE.IMG', 'M157886694LE.IMG', 'M1218802276LE.IMG', 'M132658466RE.IMG', 'M159765685LE.IMG', 'M1218802276RE.IMG', 'M132665279LE.IMG', 'M159772394LE.IMG', 'M1218802414LE.IMG', 'M132665279RE.IMG', 'M159772394RE.IMG', 'M1218802414RE.IMG', 'M132672059LE.IMG', 'M159786013LE.IMG', 'M1218816330LE.IMG', 'M132672059RE.IMG', 'M159786013RE.IMG', 'M1218816330RE.IMG', 'M132678814LE.IMG', 'M159792817LE.IMG', 'M1220430445LE.IMG', 'M132678814RE.IMG', 'M159792817RE.IMG', 'M1220430445RE.IMG', 'M132685666LE.IMG', 'M159799607LE.IMG', 'M1226298833LE.IMG', 'M132685666RE.IMG', 'M159799607RE.IMG', 'M1226298833RE.IMG', 'M132692373LE.IMG', 'M159806416LE.IMG', 'M1099891109RE.IMG', 'M1236415709RE.IMG', 'M132692373RE.IMG', 'M159806416RE.IMG', 'M1101038901LE.IMG', 'M1236415747LE.IMG', 'M132699189LE.IMG', 'M159813084LE.IMG', 'M1101038901RE.IMG', 'M1236415747RE.IMG', 'M132699189RE.IMG', 'M159813084RE.IMG', 'M1101060237LE.IMG', 'M1236422759LE.IMG', 'M1328110648LE.IMG', 'M160227845LE.IMG', 'M1101060237RE.IMG', 'M1236422759RE.IMG', 'M1328124765LE.IMG', 'M160227845RE.IMG', 'M1101074664LE.IMG', 'M1236429747LE.IMG', 'M1328145833LE.IMG', 'M160234521RE.IMG', 'M1101074664RE.IMG', 'M1236429747RE.IMG', 'M1328145833RE.IMG', 'M160241344LE.IMG', 'M1101081726LE.IMG', 'M1236443833LE.IMG', 'M1332828624LE.IMG', 'M160241344RE.IMG', 'M1101081726RE.IMG', 'M1236443833RE.IMG', 'M1332828624RE.IMG', 'M160248117LE.IMG', 'M110244608LE.IMG', 'M1236443881LE.IMG', 'M1335150933RE.IMG', 'M160248117RE.IMG', 'M110244608RE.IMG', 'M1236443881RE.IMG', 'M1335
192767225RE.IMG', 'M1184631897RE.IMG', 'M1322282087RE.IMG', 'M155077355RE.IMG', 'M192845614LE.IMG', 'M1184660286LE.IMG', 'M1322289074LE.IMG', 'M155512333LE.IMG', 'M192859993LE.IMG', 'M1186987200RE.IMG', 'M1322289074RE.IMG', 'M155512333RE.IMG', 'M192859993RE.IMG', 'M1212932117RE.IMG', 'M1322296090RE.IMG', 'M155525930LE.IMG', 'M193239646LE.IMG', 'M1215239015LE.IMG', 'M1322296237LE.IMG', 'M155525930RE.IMG', 'M1215239015RE.IMG', 'M1323403056LE.IMG', 'M155526136LE.IMG', 'M1215246017LE.IMG', 'M1323403056RE.IMG', 'M155526136RE.IMG', 'M1215246017RE.IMG', 'M1323403092LE.IMG', 'M157431518LE.IMG', 'M1215253116RE.IMG', 'M1323410081RE.IMG', 'M157431518RE.IMG', 'M1215267182LE.IMG', 'M1323424148LE.IMG', 'M157458668LE.IMG', 'M1215274138LE.IMG', 'M1323424148RE.IMG', 'M157458668RE.IMG', 'M1215274138RE.IMG', 'M1323431269LE.IMG', 'M157621918LE.IMG', 'M1215274181LE.IMG', 'M1323431269RE.IMG', 'M157621918RE.IMG', 'M1215274181RE.IMG', 'M1325773979LE.IMG', 'M157872974LE.IMG', 'M1218788292LE.IMG', 'M1325802124RE.IMG', 'M157872974RE.IMG']

# %%
link='https://quickmap.lroc.asu.edu/?extent=-90%2C-29.4584048%2C90%2C29.4584048&id=lroc&showTerrain=true&queryOpts=N4XyA&layers=NrBsFYBoAZIRnpEBmZcAsjYIHYFcAbAyAbwF8BdC0yioA&proj=10'
checker="Location is outside of bounds of.1 current projection"
header='https://wms.lroc.asu.edu/lroc/view_lroc/LRO-L-LROC-3-CDR-V1.0/'

# %%
len(name)
# Out:
# 55

# %%
dicti={'nac_name':[0],'upper_left_latitude':[0],'upper_left_longitude':[0],'upper_right_latitude':[0],'upper_right_latitude':[0],'upper_right_longitude':[0],'lower_left_latitude':[0],'lower_left_longitude':[0],'lower_right_latitude':[0],'lower_right_longitude':[0]}
#final=pd.read_csv('16.csv')
#final=final.drop(['Unnamed: 0'],axis=1)
final=pd.DataFrame(dicti)
final
# Out:
#    nac_name  upper_left_latitude  upper_left_longitude  upper_right_latitude  \
# 0         0                    0                     0                     0
#
#    upper_right_longitude  lower_left_latitude  lower_left_longitude  \
# 0                      0                    0                     0
#
#    lower_right_latitude  lower_right_longitude
# 0                     0                      0

# %%
final.columns
# Out:
# Index(['tmc_name', 'nac_name', 'upper_left_latitude', 'upper_left_longitude',
#        'upper_right_latitude', 'upper_right_longitude', 'lower_left_latitude',
#        'lower_left_longitude', 'lower_right_latitude',
#        'lower_right_longitude'],
#       dtype='object')

# %%
def line(x1,x2,y1,y2,x,y):
    if x1==x2:
        return x-x1
    elif y1==y2:
        return y-y1
    else:
        return y-y1-(y2-y1)/(x2-x1)*(x-x1)
#upper left upper right lower left lower right
#lat=y
#long=x
def inter_checker(larger_square,smaller_square):
    larg_lat=[]
    larg_long=[]
    small_lat=[]
    small_long=[]
    for i in range(0,8,2):
        larg_long.append(larger_square[i])
        small_long.append(smaller_square[i])
    for i in range(1,8,2):
        larg_lat.append(larger_square[i])
        small_lat.append(smaller_square[i])
    value1=[(1,2),(1,3)]
    value2=[(3,4),(2,4)]
    flag=0
    
    for j in range(4):
        
        for i in range(2):
            if line(larg_long[value1[i][0]-1],larg_long[value1[i][1]-1],\
                       larg_lat[value1[i][0]-1],larg_lat[value1[i][1]-1],\
                      small_long[j],small_lat[j])*line(larg_long[value2[i][0]-1],larg_long[value2[i][1]-1],\
                       larg_lat[value2[i][0]-1],larg_lat[value2[i][1]-1],\
                      small_long[j],small_lat[j]) >0:
                flag=1
    if flag:
        return False
    else:
        return True
inter_checker([0,10,10,10,0,0,10,0],[2,8,8,8,2,2,8,2]) 
# give the input of the form larger_array=[u_l_lat,u_l_long,u_r_lat,u_r_long,b_l_lat,b_l_long,b_r_lat,b_r_long]
# Out:
# True

# %%
dicti={'tmc_name':[0],'nac_name':[0],'upper_left_latitude':[0],'upper_left_longitude':[0],'upper_right_latitude':[0],'upper_right_latitude':[0],'upper_right_longitude':[0],'lower_left_latitude':[0],'lower_left_longitude':[0],'lower_right_latitude':[0],'lower_right_longitude':[0]}
faltu=pd.read_csv("faltu.csv")
faltu=faltu.drop(["Unnamed: 0"],axis=1)
faltu
# Out:
#                                            tmc_name      nac_name  \
# 0                                                 0             0
# 1                                          20210516  M193018206LC
# 2                                          20210516  M193011019RC
# 3                                          20210516  M193011019LC
# 4                                          20210516  M193004049RC
# ...                                             ...           ...
# 2487  ch2_tmc_ndn_20210516T0532066123_d_dtm_d18.zip  M102014935RC
# 2488  ch2_tmc_ndn_20210516T0532066123_d_dtm_d18.zip  M102014935LC
# 2489  ch2_tmc_ndn_20210516T0532066123_d_dtm_d18.zip  M101993512RC
# 2490  ch2_tmc_ndn_20210516T0532066123_d_dtm_d18.zip  M101993512LC
# 2491  ch2_tmc_ndn_20210516T0532066123_d_dtm_d18.zip  M101986388RC
#
#       upper_left_latitude  upper_left_longitude  upper_right_latitude  \
# 0                    0.00                  0.00                  0.00
# ...

# %%
def saver(large_sq,nam):
    url="https://wms.lroc.asu.edu/lroc/view_lroc/LRO-L-LROC-3-CDR-V1.0/"+str(nam)
    content=requests.get(url)
    htmlcontent=content.content

    #print(soup.prettify)
    lis=["Upper left latitude","Upper left longitude","Upper right latitude","Upper right longitude","Lower left latitude","Lower left longitude","Lower right latitude","Lower right longitude"]
    val=[]
    temp_link="https:"+str(htmlcontent).split("\">Download EDR")[0].split("<li><a href=\"")[-1]
    #print(temp_link)
    
    for i in lis:
        s=str(htmlcontent).split(i+"</th>\\n        <td>")
        s2=s[1].split("</td>")
        val.append(round(float(s2[0]),2))
    smaller_sq=val
    #print(val)

# %%
thread=[]
for i in range(100):
    
    for j

# %%
thread
try:
    for i in range(1000):
        c=0
        for j in nac:
            if j in np.array(final['nac_name']) or j in np.array(faltu['nac_name']):
                continue
            saver(larger_sq,j,name[i])

            if c==20:
                sleep(1.5)
                print("hi")
                break
            c+=1
            d+=1
except:
    sound.play()
sound.play()
sleep(10)
print("end")
# Out:
# end

# %%
final
# Out:
#                                           tmc_name      nac_name  \
# 0                                                0             0
# 1    ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip  M192989742RC
# 2    ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip  M192989742LC
# 3    ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip  M190659306LC
# 4    ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip  M190645001LC
# ..                                             ...           ...
# 757  ch2_tmc_ndn_20211206T0653329749_d_dtm_d18.zip  M107894126RC
# 758  ch2_tmc_ndn_20211206T0653329749_d_dtm_d18.zip  M107894126LC
# 759  ch2_tmc_ndn_20211226T2103295074_d_dtm_d18.zip  M104376990RC
# 760  ch2_tmc_ndn_20211226T2103295074_d_dtm_d18.zip  M104376990LC
# 761  ch2_tmc_ndn_20191130T0140047387_d_oth_d18.zip  M104334047RC
#
#      upper_left_latitude  upper_left_longitude  upper_right_latitude  \
# 0                   0.00                  0.00                  0.00
# ...

# %%
##### tim=0.05
writ=0.15
sleep(3)

def check():
    return False

for i in [50,51,52,53,54]:
    d=0
    auto.moveTo(316,165) #polygon
    sleep(0.15)
    auto.click()
    sleep(0.15)
    auto.click(574,166)#cross
    sleep(0.15)
    auto.click(527,167)#fill
    sleep(0.15)
    auto.write(str(ulla[i]))
    sleep(0.15)
    auto.write(',')
    sleep(writ)
    auto.write(str(ullo[i]))
    sleep(writ)
    auto.press("enter")
    sleep(2)
    if check():
        #auto.click(738,505) #center
        auto.click(311,168) #polygon

        sleep(0.25)
        continue
    auto.moveTo(737,503) #center
    sleep(0.2)
    auto.click()
    sleep(0.2)
    auto.click(574,166)#cross
    sleep(0.2)
    #repeat
    auto.write(str(urla[i]))
    sleep(writ)
    auto.write(',')
    sleep(writ)
    auto.write(str(urlo[i]))
    sleep(writ)
    auto.press("enter")
    sleep(2)
    if check():
        auto.click(311,168) #polygon

        sleep(0.25)
        continue
    auto.click(737,503) #center
    sleep(0.2)
    auto.click(574,166)#cross
    sleep(0.2)

    #repeat
    auto.write(str(brla[i]))
    sleep(writ)
    auto.write(',')
    sleep(writ)
    auto.write(str(brlo[i]))
    sleep(writ)
    auto.press("enter")
    sleep(2)
    if check():
        auto.click(311,168) #polygon

        sleep(0.25)
        continue
    auto.click(737,503) #center
    sleep(0.2)
    auto.click(574,166)#cross
    sleep(0.2)

    #repeat
    auto.write(str(blla[i]))
    sleep(writ)
    auto.write(',')
    sleep(writ)
    auto.write(str(bllo[i]))
    sleep(writ)
    auto.press("enter")
    sleep(2)
    if check():
        auto.click(311,168) #polygon

        sleep(0.25)
        continue
    auto.click(737,503) #center
    sleep(0.2)
    auto.click(737,503) #center
    sleep(0.2)
    auto.click(574,166)#cross
    sleep(9)
    sleep(0.2)
    auto.click(1132,391)
    sleep(0.2)
    auto.scroll(-10000)
    sleep(0.2)
    auto.keyDown('shift')
    auto.click(1293,878)
    auto.keyUp('shift')
    sleep(1)
    auto.keyDown("command")
    sleep(0.5)
    auto.press('c')
    sleep(1)
    auto.keyUp('command')
    sleep(1)
    auto.hotkey('command','c')
    sleep(0.5)
    auto.hotkey('command','c')
    sleep(1)
    temp=pd.read_clipboard(sep='\\s+')
    nac=np.array(temp["Add"])   #Array of string containing names of nac files
    larger_sq=[ulla[i],ullo[i],urla[i],urlo[i],blla[i],bllo[i],brla[i],brlo[i]]
    for j in nac:
        if j in np.array(final['nac_name']) or j in np.array(faltu['nac_name']):
            continue
        saver(larger_sq,j,name[i])
        if d==1000:
            d=0
            break
        d+=1
    sound.play()
    sleep(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 46
#      44 sleep(writ)
#      45 auto.press("enter")
# ---> 46 sleep(2)
#      47 if check():
#      48     auto.click(311,168) #polygon
#
# KeyboardInterrupt:

# %%
c=0

# %%
final

# %%
faltu2.close()
file.close()

# %%
i=45
c=0
for q in range(2000):
    temp=pd.read_clipboard(sep='\\s+')
    nac=np.array(temp["Add"])   #Array of string containing names of nac files
    larger_sq=[ulla[i],ullo[i],urla[i],urlo[i],blla[i],bllo[i],brla[i],brlo[i]]
    for j in nac:
        if j in np.array(final['nac_name']) or j in np.array(faltu['nac_name']):
            continue
        saver(larger_sq,j,name[i])
        if c==20:
            c=0
            print('hi')
            sleep(1)
            break
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/miniconda3/envs/pyflow/lib/python3.9/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~/opt/miniconda3/envs/pyflow/lib/python3.9/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/miniconda3/envs/pyflow/lib/python3.9/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Add'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
temp=pd.read_clipboard(sep='\\s+')
nac=np.array(temp["Add"])   #Array of string containing names of nac files
larger_sq=[ulla[i],ullo[i],urla[i],urlo[i],blla[i],bllo[i],brla[i],brlo[i]]
for j in nac:
    if j in final['nac_name'] or j in faltu['nac_name']:
        continue
    saver(larger_sq,j,name[i])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 7
#       5 if j in final['nac_name'] or j in faltu['nac_name']:
#       6     continue
# ----> 7 saver(larger_sq,j,name[i])
#
# Cell In[29], line 3, in saver(large_sq, nam, tmc)
#       1 def saver(large_sq,nam,tmc):
#       2     url="https://wms.lroc.asu.edu/lroc/view_lroc/LRO-L-LROC-3-CDR-V1.0/"+str(nam)
# ----> 3     content=requests.get(url)
#       4     htmlcontent=content.content
#       6     #print(soup.prettify)
#
# File ~/opt/miniconda3/envs/pyflow/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ...

# %%
https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0011/DATA/SCI/2012096/NAC/M188286136RE.IMG

# %%
a=pd.read_clipboard("\\s+")
a

# %% [markdown]
# # a=pd.read_clipboard(sep='\\s+')
#
# st

# %%
cep(5)
auto.moveTo(732,179)
sleep(0.5)
auto.dragTo(728,153,button='left')
auto.hotkey('command','c')
a=pd.read_clipboard('\\s+')
st=''
for i in a.columns:
    st=st+' '+i
st=st[1:]
print(st)
if st in checker:
    print(st)

# %%
a=pd.read_clipboard("\\s+")
a=np.array(a[a.columns[1]])

# %%
temp=pd.read_clipboard(sep='\\s+')
nac=np.array(temp["Add"])

# %%
lis=['','sdja']
for i in a:
    lis.append(i)
lis

# %% [markdown]
# ## Adder

# %%
final.loc[len(final.index)]=lis

# %% [markdown]
# ## Shower

# %% [markdown]
# ## Deleter

# %%
final.drop(final.tail(1).index,inplace=True) # drop last n rows
final

# %%
d

# %%
sleep(2)
auto.moveTo(732,179)
sleep(0.5)
auto.dragTo(728,153,button='left')

# %%
sleep(2)
auto.click(738,505)

# %%
tim=0.05
writ=0.15
sleep(5)

def check():
    auto.moveTo(732,179)
    sleep(0.5)
    auto.dragTo(728,153,button='left')
    auto.hotkey('command','c')
    a=pd.read_clipboard('\\s+')
    st=''
    for i in a.columns:
        st=st+' '+i
    st=st[1:]
    
    if st in checker:
        auto.click()
        clip.copy("100")
        print(st)
        return True
for i in range(len(ulla)):
    auto.click(311,168) #polygon
    sleep(0.15)
    auto.click(574,166)#cross
    sleep(0.15)
    auto.click(527,167)#fill
    sleep(0.15)
    auto.write(str(2))
    sleep(0.15)
    auto.write(',')
    sleep(writ)
    auto.write(str(9))
    sleep(writ)
    auto.press("enter")
    sleep(0.15)
    if check():
        #auto.click(738,505) #center
        auto.click(311,168) #polygon
        sleep(0.25)
        continue
    auto.moveTo(730,487) #center
    sleep(0.2)
    auto.click()
    sleep(0.2)
    auto.click(574,166)#cross
    sleep(0.2)
    #repeat
    auto.write(str(2))
    sleep(writ)
    auto.write(',')
    sleep(writ)
    auto.write(str(10))
    sleep(writ)
    auto.press("enter")
    sleep(0.2)
    if check():
        auto.click(311,168) #polygon
        sleep(0.25)
        continue
    auto.click(730,487) #center
    sleep(0.2)
    auto.click(574,166)#cross
    sleep(0.2)
    
    #repeat
    auto.write(str(3))
    sleep(writ)
    auto.write(',')
    sleep(writ)
    auto.write(str(10))
    sleep(writ)
    auto.press("enter")
    sleep(0.2)
    if check():
        auto.click(311,168) #polygon
        sleep(0.25)
        continue
    auto.click(730,487) #center
    sleep(0.2)
    auto.click(574,166)#cross
    sleep(0.2)
    
    #repeat
    auto.write(str(3))
    sleep(writ)
    auto.write(',')
    sleep(writ)
    auto.write(str(9))
    sleep(writ)
    auto.press("enter")
    sleep(0.2)
    if check():
        auto.click(311,168) #polygon
        sleep(0.25)
        continue
    auto.click(730,487) #center
    sleep(0.2)
    auto.click(730,487) #center
    sleep(0.2)
    auto.click(574,166)#cross
    sleep(0.2)
    sleep(0.2)
    auto.click(1132,391)
    sleep(0.2)
    auto.scroll(-20000)
    sleep(0.2)
    auto.keyDown('shift')
    auto.click(1293,878)
    auto.keyUp('shift')
    sleep(0.2)
    auto.hotkey('command','c')
    sleep(0.2)
    temp=pd.read_clipboard(sep='\\s+')
    nac=np.array(temp["Add"])   #Array of string containing names of nac files
    larger_sq=[ulla[i],ullo[i],urla[i],urlo[i],blla[i],bllo[i],brla[i],brlo[i]]
    for j in nac:
        saver(larger_sq,j,name[i])

# %%
auto.moveTo(1132,391)

# %%
clip.copy("100")

# %%
auto.position(311,165)

# %%
temp

# %%
sleep(3)
auto.hotkey('command','c')
pd.read_clipboard(sep='\\s+')

# %%
faltu2.close()

# %%
file.close()

# %%
file=open("Bash.txt",'r')
print(file.read())
file.close()

# %%
file=open("Bash.txt",'a')

# %%
final

# %%
lis=[0]
for i in range(16):
    lis.append('ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip')
final['tmc_name']=lis

# %%
final.to_csv("16.csv")

# %%
faltu

# %%
faltu

# %%
d

# %%
temp

# %%
def saver(large_sq,val,tmc):
    sleep(0.05)
    auto.hotkey('command','t')
    sleep(0.07)
    value=header+val
    clip.copy(value)
    sleep(0.5)
    auto.hotkey("command",'v')
    #auto.write(value)
    sleep(0.2)
    auto.press('enter')
    sleep(1.5)
    count=0
    while True:
        auto.moveTo(291,179)
        sleep(0.5)
        auto.dragTo(116,173,button='left')
        auto.hotkey('command','c')
        auto.hotkey('command','c')
        auto.hotkey('command','c')
        auto.hotkey('command','c')
        auto.hotkey('command','c')
        if clip.paste() in "Observation":
            break
        if count==15:
            return
        count+=1
        sleep(0.5)
    auto.click(1085,699)
    sleep(0.55)
    auto.click(99,269,button='right')
    sleep(0.55)
    auto.moveTo(141,403)
    sleep(0.5)
    auto.click()
    sleep(1)
    temp_link=clip.paste()
    print(temp_link)
    sleep(0.5)

    auto.scroll(-20)
    sleep(0.5)
    auto.moveTo(10,734)
    sleep(0.1)
    auto.dragTo(223,864,button='left')
    sleep(0.5)
    auto.keyDown('command')
    sleep(0.5)
    auto.press('c')
    sleep(0.5)
    auto.keyUp('command')
    a=pd.read_clipboard("\\s+")
    smaller_sq=np.array(a[a.columns[1]])
    if inter_checker(larger_sq,smaller_sq):
        lis=[tmc,val]
        for i in smaller_sq:
            lis.append(i)
        final.loc[len(final.index)]=lis
        #auto.scroll(20)
        #sleep(1)
        #auto.click(85,269)
        #sleep(3.05)
        #auto.click(1422,868)
        file.write(temp_link+'\n')
        
    else:
        flag=0
        for q in range(len(urlo)):
            lar=[ulla[q],ullo[q],urla[q],urlo[q],blla[q],bllo[q],brla[q],brlo[q]]
            small=smaller_sq
            if inter_checker(lar,small):
                lis=[name[q],val]
                for i in smaller_sq:
                    lis.append(i)
                final.loc[len(final.index)]=lis
                flag=1
                #auto.scroll(20)
                #sleep(1)
                #auto.click(85,269)
                #sleep(6.05)
                #auto.click(1422,868)
                file.write(temp_link+'\n')
                break
        if flag==0:
            lis=[name[q],val]
            for i in smaller_sq:
                lis.append(i)
            
            faltu.loc[len(faltu.index)]=lis
            faltu2.write(temp_link+'\n')
    auto.hotkey("command","w")
    sleep(0.1)

# %%
sleep(5)
for i in range(45,len(ulla)):
    auto.moveTo(316,165) #polygon
    sleep(0.15)
    auto.click()
    sleep(0.15)
    auto.click(574,166)#cross
    sleep(0.15)
    auto.click(527,167)#fill
    sleep(0.15)
    auto.write(str(ulla[i]))
    sleep(0.15)
    auto.write(',')
    sleep(writ)
    auto.write(str(ullo[i]))
    sleep(writ)
    auto.press("enter")
    sleep(0.15)
    if check():
        #auto.click(738,505) #center
        auto.click(311,168) #polygon

        sleep(0.25)
        continue
    auto.moveTo(737,503) #center
    sleep(0.2)
    auto.click()
    sleep(0.2)
    auto.click(574,166)#cross
    sleep(0.2)
    #repeat
    auto.write(str(urla[i]))
    sleep(writ)
    auto.write(',')
    sleep(writ)
    auto.write(str(urlo[i]))
    sleep(writ)
    auto.press("enter")
    sleep(0.2)
    if check():
        auto.click(311,168) #polygon

        sleep(0.25)
        continue
    auto.click(737,503) #center
    sleep(0.2)
    auto.click(574,166)#cross
    sleep(0.2)

    #repeat
    auto.write(str(brla[i]))
    sleep(writ)
    auto.write(',')
    sleep(writ)
    auto.write(str(brlo[i]))
    sleep(writ)
    auto.press("enter")
    sleep(0.2)
    if check():
        auto.click(311,168) #polygon

        sleep(0.25)
        continue
    auto.click(737,503) #center
    sleep(0.2)
    auto.click(574,166)#cross
    sleep(0.2)

    #repeat
    auto.write(str(blla[i]))
    sleep(writ)
    auto.write(',')
    sleep(writ)
    auto.write(str(bllo[i]))
    sleep(writ)
    auto.press("enter")
    sleep(0.2)
    if check():
        auto.click(311,168) #polygon

        sleep(0.25)
        continue
    auto.click(737,503) #center
    sleep(0.2)
    auto.click(737,503) #center
    sleep(0.2)
    auto.click(574,166)#cross
    sleep(9)

# %% [markdown]
# ###

# %% [markdown]
# # def check():
#     auto.moveTo(732,179)
#     sleep(0.5)
#     auto.dragTo(728,153,button='left')
#     auto.hotkey('command','c')
#     a=pd.read_clipboard('\\s+')
#     st=''
#     for i in a.columns:
#         st=st+' '+i
#     st=st[1:]
#
#     if st in checker:
#         auto.click()
#         print(st)
#         clip.copy("100")
#         return True
#
# ### def check():
#     auto.moveTo(732,179)
#     sleep(0.5)
#     auto.dragTo(728,153,button='left')
#     auto.hotkey('command','c')
#     a=pd.read_clipboard('\\s+')
#     st=''
#     for i in a.columns:
#         st=st+' '+i
#     st=st[1:]
#
#     if st in checker:
#         auto.click()
#         print(st)
#         clip.copy("100")
#         return True

# %%
tim=0.05
writ=0.15
sleep(3)
lis=[]
def check():
    return False
try:
    for i in [45,50,51,52,53,54]:
        d=0
        auto.moveTo(316,165) #polygon
        sleep(0.15)
        auto.click()
        sleep(0.15)
        auto.click(574,166)#cross
        sleep(0.15)
        auto.click(527,167)#fill
        sleep(0.15)
        auto.write(str(round(ulla[i],2)))
        sleep(0.15)
        auto.write(',')
        sleep(writ)
        auto.write(str(round(ullo[i],2)))
        sleep(0.5)
        auto.press("enter")
        sleep(2)
        if check():
            #auto.click(738,505) #center
            auto.click(311,168) #polygon

            sleep(0.25)
            continue
        auto.moveTo(737,503) #center
        sleep(0.2)
        auto.click()
        sleep(0.2)
        auto.click(574,166)#cross
        sleep(0.2)
        #repeat
        auto.write(str(round(urla[i],2)))
        sleep(writ)
        auto.write(',')
        sleep(writ)
        auto.write(str(round(urlo[i],2)))
        sleep(0.5)
        auto.press("enter")
        sleep(2)
        if check():
            auto.click(311,168) #polygon

            sleep(0.25)
            continue
        auto.click(737,503) #center
        sleep(0.2)
        auto.click(574,166)#cross
        sleep(2)

        #repeat
        auto.write(str(round(brla[i],2)))
        sleep(writ)
        auto.write(',')
        sleep(writ)
        auto.write(str(round(brlo[i],2)))
        sleep(0.5)
        auto.press("enter")
        sleep(2)
        if check():
            auto.click(311,168) #polygon

            sleep(0.25)
            continue
        auto.click(737,503) #center
        sleep(0.2)
        auto.click(574,166)#cross
        sleep(0.2)

        #repeat
        auto.write(str(round(blla[i],2)))
        sleep(writ)
        auto.write(',')
        sleep(writ)
        auto.write(str(round(bllo[i],2)))
        sleep(writ)
        auto.press("enter")
        sleep(2)
        if check():
            auto.click(311,168) #polygon

            sleep(0.25)
            continue
        auto.click(737,503) #center
        sleep(0.2)
        auto.click(737,503) #center
        sleep(0.2)
        auto.click(574,166)#cross
        sleep(9)
        prev_val=''
        while True:
            auto.doubleClick()
            auto.scroll(-1)
            sleep(1)
            val=clip.paste()
            if val==prev_val:
                continue
            lis.append(val)
            print(val)
except:
    print("hi")

# %%
sleep(2)
auto.hotkey("command",'t')
sleep(0.5)
auto.hotkey("command",'v')
sleep(0.5)
auto.press('enter')
while True:
    auto.moveTo(291,179)
    sleep(0.25)
    auto.dragTo(116,173,button='left')
    auto.hotkey('command','c')
    auto.hotkey('command','c')
    auto.hotkey('command','c')
    auto.hotkey('command','c')
    auto.hotkey('command','c')
    if clip.paste() in "Observation":
        print("yes")
        break
    else:
        print("no")
    sleep(0.5)

# %%
tim=0.05
writ=0.15
sleep(3)
lis=[]
def check():
    return False
try:
    for i in [45,50,51,52,53,54]:
        d=0
        auto.moveTo(316,165) #polygon
        sleep(0.15)
        auto.click()
        sleep(0.15)
        auto.click(574,166)#cross
        sleep(0.15)
        auto.click(527,167)#fill
        sleep(0.15)
        auto.write(str(round(ulla[i],2)))
        sleep(0.15)
        auto.write(',')
        sleep(writ)
        auto.write(str(round(ullo[i],2)))
        sleep(0.5)
        auto.press("enter")
        sleep(2)
        if check():
            #auto.click(738,505) #center
            auto.click(311,168) #polygon

            sleep(0.25)
            continue
        auto.moveTo(737,503) #center
        sleep(0.2)
        auto.click()
        sleep(0.2)
        auto.click(574,166)#cross
        sleep(0.2)
        #repeat
        auto.write(str(round(urla[i],2)))
        sleep(writ)
        auto.write(',')
        sleep(writ)
        auto.write(str(round(urlo[i],2)))
        sleep(0.5)
        auto.press("enter")
        sleep(2)
        if check():
            auto.click(311,168) #polygon

            sleep(0.25)
            continue
        auto.click(737,503) #center
        sleep(0.2)
        auto.click(574,166)#cross
        sleep(2)

        #repeat
        auto.write(str(round(brla[i],2)))
        sleep(writ)
        auto.write(',')
        sleep(writ)
        auto.write(str(round(brlo[i],2)))
        sleep(0.5)
        auto.press("enter")
        sleep(2)
        if check():
            auto.click(311,168) #polygon

            sleep(0.25)
            continue
        auto.click(737,503) #center
        sleep(0.2)
        auto.click(574,166)#cross
        sleep(0.2)

        #repeat
        auto.write(str(round(blla[i],2)))
        sleep(writ)
        auto.write(',')
        sleep(writ)
        auto.write(str(round(bllo[i],2)))
        sleep(writ)
        auto.press("enter")
        sleep(2)
        if check():
            auto.click(311,168) #polygon

            sleep(0.25)
            continue
        auto.click(737,503) #center
        sleep(0.2)
        auto.click(737,503) #center
        sleep(0.2)
        auto.click(574,166)#cross
        sleep(9)
        prev_val=''
        while True:
            auto.doubleClick()
            auto.scroll(-1)
            sleep(1)
            val=clip.paste()
            if val==prev_val:
                continue
            lis.append(val)
            print(val)
except:
    print("hi")

# %%
sleep(2)
auto.click(button='left')
sleep(0.2)
auto.click(button='left')

# %%
final.to_csv("16.csv")
faltu.to_csv("faltu.csv")

# %% [markdown]
# #

# %%
final
# Out:
#                                           tmc_name      nac_name  \
# 0                                                0             0
# 1    ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip  M192989742RC
# 2    ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip  M192989742LC
# 3    ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip  M190659306LC
# 4    ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip  M190645001LC
# ..                                             ...           ...
# 758  ch2_tmc_ndn_20211206T0653329749_d_dtm_d18.zip  M107894126LC
# 759  ch2_tmc_ndn_20211226T2103295074_d_dtm_d18.zip  M104376990RC
# 760  ch2_tmc_ndn_20211226T2103295074_d_dtm_d18.zip  M104376990LC
# 761  ch2_tmc_ndn_20191130T0140047387_d_oth_d18.zip  M104334047RC
# 762  ch2_tmc_ndn_20211226T2103295074_d_dtm_d18.zip  M192810060RC
#
#      upper_left_latitude  upper_left_longitude  upper_right_latitude  \
# 0                   0.00                  0.00                  0.00
# ...

# %%
faltu
# Out:
#                                            tmc_name      nac_name  \
# 0                                                 0             0
# 1                                          20210516  M193018206LC
# 2                                          20210516  M193011019RC
# 3                                          20210516  M193011019LC
# 4                                          20210516  M193004049RC
# ...                                             ...           ...
# 2491  ch2_tmc_ndn_20210516T0532066123_d_dtm_d18.zip  M101986388RC
# 2492  ch2_tmc_ndn_20210516T0532066123_d_dtm_d18.zip  M192810089RC
# 2493  ch2_tmc_ndn_20210516T0532066123_d_dtm_d18.zip  M192810089LC
# 2494  ch2_tmc_ndn_20210516T0532066123_d_dtm_d18.zip  M192810060LC
# 2495  ch2_tmc_ndn_20210516T0532066123_d_dtm_d18.zip  M192802929RC
#
#       upper_left_latitude  upper_left_longitude  upper_right_latitude  \
# 0                    0.00                  0.00                  0.00
# ...

# %%
final.drop(['tmc_name'],axis=1).to_csv("Ankesh_nac.csv")

# %%
file.close()

# %%
file=open("Bash.txt")

# %%
l=file.readlines()

# %%
final
# Out:
#                                           tmc_name      nac_name  \
# 0                                                0             0
# 1    ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip  M192989742RC
# 2    ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip  M192989742LC
# 3    ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip  M190659306LC
# 4    ch2_tmc_ndn_20220518T2239379187_d_oth_d18.zip  M190645001LC
# ..                                             ...           ...
# 758  ch2_tmc_ndn_20211206T0653329749_d_dtm_d18.zip  M107894126LC
# 759  ch2_tmc_ndn_20211226T2103295074_d_dtm_d18.zip  M104376990RC
# 760  ch2_tmc_ndn_20211226T2103295074_d_dtm_d18.zip  M104376990LC
# 761  ch2_tmc_ndn_20191130T0140047387_d_oth_d18.zip  M104334047RC
# 762  ch2_tmc_ndn_20211226T2103295074_d_dtm_d18.zip  M192810060RC
#
#      upper_left_latitude  upper_left_longitude  upper_right_latitude  \
# 0                   0.00                  0.00                  0.00
# ...

# %%
import pyautogui as auto
from time import sleep()

# %%
faltu.to_csv("faltu.csv")

# %%
while(True):
    auto.moveTo(600,600)
    sleep(170)
    auto.moveTo(700,700)
    sleep(170)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 while(True):
# ----> 2     auto.moveTo(600,600)
#       3     sleep(170)
#       4     auto.moveTo(700,700)
#
# NameError: name 'auto' is not defined

# %% [markdown]
# ####
