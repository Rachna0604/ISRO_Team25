# %%
import pandas as pd
import numpy as np

# %%
class Point:
	def __init__(self, x, y):
		self.x = x
		self.y = y

class line:
	def __init__(self, p1, p2):
		self.p1 = p1
		self.p2 = p2

def onLine(l1, p):
	# Check whether p is on the line or not
	if (
		p.x <= max(l1.p1.x, l1.p2.x)
		and p.x <= min(l1.p1.x, l1.p2.x)
		and (p.y <= max(l1.p1.y, l1.p2.y) and p.y <= min(l1.p1.y, l1.p2.y))
	):
		return True
	return False

def direction(a, b, c):
	val = (b.y - a.y) * (c.x - b.x) - (b.x - a.x) * (c.y - b.y)
	if val == 0:
		# Colinear
		return 0
	elif val < 0:
		# Anti-clockwise direction
		return 2
	# Clockwise direction
	return 1

def isIntersect(l1, l2):
	# Four direction for two lines and points of other line
	dir1 = direction(l1.p1, l1.p2, l2.p1)
	dir2 = direction(l1.p1, l1.p2, l2.p2)
	dir3 = direction(l2.p1, l2.p2, l1.p1)
	dir4 = direction(l2.p1, l2.p2, l1.p2)

	# When intersecting
	if dir1 != dir2 and dir3 != dir4:
		return True

	# When p2 of line2 are on the line1
	if dir1 == 0 and onLine(l1, l2.p1):
		return True

	# When p1 of line2 are on the line1
	if dir2 == 0 and onLine(l1, l2.p2):
		return True

	# When p2 of line1 are on the line2
	if dir3 == 0 and onLine(l2, l1.p1):
		return True

	# When p1 of line1 are on the line2
	if dir4 == 0 and onLine(l2, l1.p2):
		return True

	return False

def checkInside(poly, n, p):
	# When polygon has less than 3 edge, it is not polygon
	if n < 3:
		return False

	# Create a point at infinity, y is same as point p
	exline = line(p, Point(9999, p.y))
	count = 0
	i = 0
	while True:
		# Forming a line from two consecutive points of poly
		side = line(poly[i], poly[(i + 1) % n])
		if isIntersect(side, exline):
			# If side is intersects ex
			if (direction(side.p1, p, side.p2) == 0):
				return onLine(side, p);
			count += 1
		
		i = (i + 1) % n;
		if i == 0:
			break

	# When count is odd
	return count & 1;


# Driver code
def polygon_maker(arr):
    return [Point(arr[0],arr[1]),Point(arr[2],arr[3]),Point(arr[4],arr[5]),Point(arr[6],arr[7])]
polygon = [ Point( 0, 0 ), Point( 10, 0 ), Point( 10, 10 ), Point( 0, 10 ) ];
p = Point( 5, 1);
n = 4;

# Function call
checkInside(polygon,n,p)
# Out:
# 1

# %%
df=pd.read_csv("200 se tmc.csv")
df=df.drop([df.columns[0]],axis=1)
df
# Out:
#                                            Filename                Unnamed: 2  \
# 0     ch2_tmc_ncf_20200620T0405094886_d_img_d18.zip  2020-06-20T04:05:09.488Z
# 1     ch2_tmc_ncn_20200526T0526071367_d_img_d18.zip  2020-05-26T05:26:07.136Z
# 2     ch2_tmc_ncf_20220105T0947347394_d_img_d18.zip  2022-01-05T09:47:34.739Z
# 3     ch2_tmc_ncn_20200629T1039007613_d_img_d18.zip  2020-06-29T10:39:00.761Z
# 4     ch2_tmc_ncn_20221202T1529533603_d_img_d32.zip  2022-12-02T15:29:53.360Z
# ...                                             ...                       ...
# 3041  ch2_tmc_ncf_20191207T1633073885_d_img_d18.zip  2019-12-07T16:33:07.388Z
# 3042  ch2_tmc_nca_20191207T1633073885_d_img_d18.zip  2019-12-07T16:33:07.388Z
# 3043  ch2_tmc_ncn_20191206T1305163478_d_img_d18.zip  2019-12-06T13:05:16.347Z
# 3044  ch2_tmc_ncf_20191206T1305163478_d_img_d18.zip  2019-12-06T13:05:16.347Z
# 3045  ch2_tmc_nca_20191206T1305163478_d_img_d18.zip  2019-12-06T13:05:16.347Z
#
# ...

# %%
for i in df.index:
    if df.iloc[i,0]=='ch2_tmc_nca_20201123T0908524320_d_img_d18.zip':
        print(i)
# Out:
# 2540

# %%
df.iloc[1,0]
# Out:
# 'ch2_tmc_ncn_20200526T0526071367_d_img_d18.zip'

# %%
nac=pd.read_csv("nac_collected_data.csv")
nac=nac.drop([nac.columns[0]],axis=1)
nac
# Out:
#           nac_name  upper_left_latitude  upper_left_longitude  \
# 0                0                 0.00                  0.00
# 1     M192989742RC                25.61                355.48
# 2     M192989742LC                25.61                355.73
# 3     M190659306LC                21.01                351.58
# 4     M190645001LC                20.62                353.70
# ...            ...                  ...                   ...
# 3253  M101986388RC               -28.40                 26.13
# 3254  M192810089RC               -19.93                 21.53
# 3255  M192810089LC               -19.93                 21.66
# 3256  M192810060LC               -23.86                 21.59
# 3257  M192802929RC               -20.60                 22.59
#
#       upper_right_latitude  upper_right_longitude  lower_right_latitude  \
# 0                     0.00                   0.00                  0.00
# 1                    25.62                 355.22                 26.70
# ...

# %%
nac
# Out:
#           nac_name  upper_left_latitude  upper_left_longitude  \
# 0                0                 0.00                  0.00
# 1     M192989742RC                25.61                355.48
# 2     M192989742LC                25.61                355.73
# 3     M190659306LC                21.01                351.58
# 4     M190645001LC                20.62                353.70
# ...            ...                  ...                   ...
# 3253  M101986388RC               -28.40                 26.13
# 3254  M192810089RC               -19.93                 21.53
# 3255  M192810089LC               -19.93                 21.66
# 3256  M192810060LC               -23.86                 21.59
# 3257  M192802929RC               -20.60                 22.59
#
#       upper_right_latitude  upper_right_longitude  lower_right_latitude  \
# 0                     0.00                   0.00                  0.00
# 1                    25.62                 355.22                 26.70
# ...

# %%
ulla=np.round_(np.array(df['upper_left_latitude']),decimals=2)
ullo=np.round_(np.array(df['upper_left_longitude']),decimals=2)
urla=np.round_(np.array(df['upper_right_latitude']),decimals=2)
urlo=np.round_(np.array(df['upper_right_longitude']),decimals=2)
brla=np.round_(np.array(df['lower_right_latitude']),decimals=2)
brlo=np.round_(np.array(df['lower_right_longitude']),decimals=2)
blla=np.round_(np.array(df['lower_left_latitude']),decimals=2)
bllo=np.round_(np.array(df['lower_left_longitude']),decimals=2)
lis=[]
for i in ullo:
    if i<0:
        lis.append(i+360)
    else:
        lis.append(i)
ullo=np.array(lis)
lis=[]
for i in urlo:
    if i<0:
        lis.append(i+360)
    else:
        lis.append(i)
urlo=np.array(lis)
lis=[]
for i in brlo:
    if i<0:
        lis.append(i+360)
    else:
        lis.append(i)
brlo=np.array(lis)
lis=[]
for i in bllo:
    if i<0:
        lis.append(i+360)
    else:
        lis.append(i)
bllo=np.array(lis)
df['upper_left_longitude']=ullo
df['upper_right_longitude']=urlo
df['lower_left_longitude']=bllo
df['lower_right_longitude']=brlo

# %%
dicti={'nac':[0],'tmc':[0]}
final=pd.DataFrame(dicti)
final
# Out:
#    nac  tmc
# 0    0    0

# %%
nac
# Out:
#           nac_name  upper_left_latitude  upper_left_longitude  \
# 0                0                 0.00                  0.00
# 1     M192989742RC                25.61                355.48
# 2     M192989742LC                25.61                355.73
# 3     M190659306LC                21.01                351.58
# 4     M190645001LC                20.62                353.70
# ...            ...                  ...                   ...
# 3253  M101986388RC               -28.40                 26.13
# 3254  M192810089RC               -19.93                 21.53
# 3255  M192810089LC               -19.93                 21.66
# 3256  M192810060LC               -23.86                 21.59
# 3257  M192802929RC               -20.60                 22.59
#
#       upper_right_latitude  upper_right_longitude  lower_right_latitude  \
# 0                     0.00                   0.00                  0.00
# 1                    25.62                 355.22                 26.70
# ...

# %%
for i in np.array(nac.index):
    if i==0:
        continue
    smaller_sq=np.array(nac.iloc[i,1:])
    for j in df.index:
        larger_sq=np.array(df.iloc[j,6:14])
        flag=0
        for k in range(0,8,2):

            if checkInside(polygon_maker(larger_sq),4,Point(smaller_sq[k],smaller_sq[k+1]))==False:
                flag+=1
                break
        if flag==0:
            lis=[nac.iloc[i,0],df.iloc[j,0]]
            final.loc[len(final.index)]=lis

# %%
final
# Out:
#                nac                                            tmc
# 0                0                                              0
# 1     M192989742LC  ch2_tmc_ncn_20220518T2239379187_d_img_d18.zip
# 2     M192989742LC  ch2_tmc_ncf_20220518T2239379155_d_img_d18.zip
# 3     M190630731LC  ch2_tmc_nca_20211219T1607373360_d_img_d32.zip
# 4     M188300425LC  ch2_tmc_ncf_20191213T1738376423_d_img_d18.zip
# ...            ...                                            ...
# 4988  M192810089LC  ch2_tmc_ncf_20200204T0039413128_d_img_gds.zip
# 4989  M192810060LC  ch2_tmc_ncn_20220518T1459006639_d_img_d18.zip
# 4990  M192810060LC  ch2_tmc_ncn_20200204T0039413128_d_img_gds.zip
# 4991  M192810060LC  ch2_tmc_ncf_20200204T0039413128_d_img_gds.zip
# 4992  M192810060LC  ch2_tmc_nca_20200204T0039413128_d_img_gds.zip
#
# [4993 rows x 2 columns]

# %%
final.to_csv("nac_tmc_overlapping.csv")

# %%
# Main multi threading code that check whether the nac image lies under the tmc image or not

for th in range(99):
    threads=[]
    #for i in range(1+t*33,33+t*33):
    if 33+th*33<3258:
        t=threading.Thread(target=intersecter,args=(1+th*33,33+th*33))
    else:
        t=threading.Thread(target=intersecter,args=(1+th*33,3258))
    threads.append(t)
    t.start()
for t in threads:
    t.join()
    
    val=7
# Out:
# Exception in thread Thread-202:
# Traceback (most recent call last):
#   File "/Users/adityaruhela/opt/miniconda3/envs/pyflow/lib/python3.9/threading.py", line 980, in _bootstrap_inner
#     self.run()
#   File "/Users/adityaruhela/opt/miniconda3/envs/pyflow/lib/python3.9/threading.py", line 917, in run
#     self._target(*self._args, **self._kwargs)
#   File "/var/folders/63/2gnzxxd10lv3m734r72wrw3c0000gn/T/ipykernel_15057/3499097912.py", line 16, in intersecter
#   File "/Users/adityaruhela/opt/miniconda3/envs/pyflow/lib/python3.9/site-packages/pandas/core/indexing.py", line 818, in __setitem__
#     iloc._setitem_with_indexer(indexer, value, self.name)
#   File "/Users/adityaruhela/opt/miniconda3/envs/pyflow/lib/python3.9/site-packages/pandas/core/indexing.py", line 1785, in _setitem_with_indexer
# Exception in thread Thread-187:
# Traceback (most recent call last):
#   File "/Users/adityaruhela/opt/miniconda3/envs/pyflow/lib/python3.9/threading.py", line 980, in _bootstrap_inner
# ...

# %%
file=open("HPC_bash.txt",'w')

# %%
for i in useful_links:
    file.write(i+'\n')
file.close()

# %%
file=open('HPC_bash.txt','r')
print(len(file.readlines()))
file.close()
# Out:
# 2871

# %%
lis=[]

# %%
a=open("Reader2.txt")

# %%
useful_links=a.readlines()

# %%
executer=open("executer.sh",'w')
executer.write("#!/bin/bash\n")
# Out:
# 12

# %%
lis=[]

# %%
# this piece of code is might throw an error, indicates end of the file
for i in range(0,10):
    file=open("HPC_bash_"+str(i)+".sh",'w')
    file.write("#!/bin/bash\n")
    for j in range(0+i*10,10+i*10):
        file.write("wget "+useful_links[j][:-1]+"\n")
    file.close()
    executer.write("chmod +x "+"HPC_bash_"+str(i)+".sh"+"\n")
    lis.append("HPC_bash_"+str(i)+".sh")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 5
#       3 file.write("#!/bin/bash\n")
#       4 for j in range(0+i*10,10+i*10):
# ----> 5     file.write("wget "+useful_links[j][:-1]+"\n")
#       6 file.close()
#       7 executer.write("chmod +x "+"HPC_bash_"+str(i)+".sh"+"\n")
#
# IndexError: list index out of range

# %%
lis.append('HPC_bash_9.sh')

# %%
executer.close()

# %%
l=[]
for i in range(0,100):
    for j in range(0+i*300,300+i*300):
        l.append(j)

# %%
l2=[]
for i in range(3000):
    l2.append(i)
l2==l
# Out:
# True

# %%
print(lis)
# Out:
# ['HPC_bash_0.sh', 'HPC_bash_1.sh', 'HPC_bash_2.sh', 'HPC_bash_3.sh', 'HPC_bash_4.sh', 'HPC_bash_5.sh', 'HPC_bash_6.sh', 'HPC_bash_7.sh', 'HPC_bash_8.sh', 'HPC_bash_9.sh', 'HPC_bash_10.sh', 'HPC_bash_11.sh']

# %%
f2=open("Downloader.sh",'r')
useful_links=f2.readlines()

# %%
useful_links
# Out:
# ['wget https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0025/DATA/ESM2/2015333/NAC/M1203466025RE.IMG\n',
#  'wget https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0008/DATA/SCI/2011254/NAC/M170389818RE.IMG\n',
#  'wget https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0024/DATA/ESM2/2015184/NAC/M1190562100RE.IMG\n',
#  'wget https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0010/DATA/SCI/2012039/NAC/M183360120LE.IMG\n',
#  'wget https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0017/DATA/ESM/2013328/NAC/M1139929200LE.IMG\n',
#  'wget https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0041A/DATA/ESM4/2019288/NAC/M1325752825RE.IMG\n',
#  'wget https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0018/DATA/ESM/2014072/NAC/M1149316946LE.IMG\n',
#  'wget https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0001/DATA/MAP/2009302/NAC/M111450544LE.IMG\n',
# ...

# %%
lis=['HPC_bash_0.sh', 'HPC_bash_1.sh', 'HPC_bash_2.sh', 'HPC_bash_3.sh', 'HPC_bash_4.sh', 'HPC_bash_5.sh', 'HPC_bash_6.sh', 'HPC_bash_7.sh', 'HPC_bash_8.sh','HPC_bash_9.sh','HPC_bash_10.sh']

# %%
lis
# Out:
# ['HPC_bash_0.sh',
#  'HPC_bash_1.sh',
#  'HPC_bash_2.sh',
#  'HPC_bash_3.sh',
#  'HPC_bash_4.sh',
#  'HPC_bash_5.sh',
#  'HPC_bash_6.sh',
#  'HPC_bash_7.sh',
#  'HPC_bash_8.sh',
#  'HPC_bash_9.sh',
#  'HPC_bash_10.sh',
#  'HPC_bash_11.sh']

# %%
file=open("Uploader.sh",'w')
for i in lis:
    file.write( "scp -P 22 "+i+" b21082@10.8.1.19:/wd/users/b21082/downloads" +"\n")
file.write( "scp -P 22 "+"executer.sh"+" b21082@10.8.1.19:/wd/users/b21082/downloads" +"\n")
file.write( "scp -P 22 "+"subp.py"+" b21082@10.8.1.19:/wd/users/b21082/downloads" +"\n")
file.close()

# %%
s=open("Reader4.txt",'r')
lis=s.readlines()
lis
# Out:
# ['M1108418696LE.png  M1155535992RE.png  M1317866853RE.png  M1387140621RE.png\n',
#  'M1108418696RE.png  M1175538221LE.png  M1322563400RE.png  M1422330896LE.png\n',
#  'M1129625059LE.png  M1243793205LE.png  M1336660583LE.png  M1422330896RE.png\n',
#  'M1131978825RE.png  M1247328164LE.png  M1336667665RE.png  M165978955LE.png\n',
#  'M1146112778RE.png  M1269660582RE.png  M1350761945RE.png  M165978955RE.png\n',
#  'M1151993612LE.png  M1272008542LE.png  M1374246998RE.png  M178942582RE.png\n',
#  'M1151993612RE.png  M1313163693LE.png  M1385982865RE.png\n',
#  'M1155535992LE.png  M1317866853LE.png  M1387140621LE.png']

# %%
str_lis=[]
for i in lis:
    for j in i[:-1].split():
        if j[0]=="M":
            str_lis.append(j)

# %%
print(str_lis)
# Out:
# ['M1108418696LE.png', 'M1155535992RE.png', 'M1317866853RE.png', 'M1387140621RE.png', 'M1108418696RE.png', 'M1175538221LE.png', 'M1322563400RE.png', 'M1422330896LE.png', 'M1129625059LE.png', 'M1243793205LE.png', 'M1336660583LE.png', 'M1422330896RE.png', 'M1131978825RE.png', 'M1247328164LE.png', 'M1336667665RE.png', 'M165978955LE.png', 'M1146112778RE.png', 'M1269660582RE.png', 'M1350761945RE.png', 'M165978955RE.png', 'M1151993612LE.png', 'M1272008542LE.png', 'M1374246998RE.png', 'M178942582RE.png', 'M1151993612RE.png', 'M1313163693LE.png', 'M1385982865RE.png', 'M1155535992LE.png', 'M1317866853LE.png', 'M1387140621LE.pn']

# %%
lis=[]

# %%
second=[]
for i in str_lis:
    for j in useful_links:
        if i in j:
            second.append(j)

# %%
second
# Out:
# ['https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0015/DATA/ESM/2013110/NAC/M1121081104RE.IMG',
#  'https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0022/DATA/ESM2/2015007/NAC/M1175261010LE.IMG',
#  'https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0031/DATA/ESM3/2017093/NAC/M1245853848RE.IMG',
#  'https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0038B/DATA/ESM3/2019043/NAC/M1304639475LE.IMG',
#  'https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0040C/DATA/ESM3/2019247/NAC/M1322275060LE.IMG',
#  'https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0049B/DATA/ESM4/2021318/NAC/M1391513796RE.IMG',
#  'https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0007/DATA/SCI/2011104/NAC/M157431518RE.IMG',
#  'https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0008/DATA/SCI/2011232/NAC/M168495900LE.IMG',
#  'https://pds.lroc.asu.edu/data/LRO-L-LROC-2-EDR-V1.0/LROLRC_0010/DATA/SCI/2012011/NAC/M180965635LE.IMG',
# ...

# %%
final=[]
for i in useful_links:
    if i not in second:
        final.append(i)

# %%
len(final)
# Out:
# 1891

# %%
executer=open("executer.sh",'w')
executer.write("#!/bin/bash\n")
# Out:
# 12

# %%
len(final)
# Out:
# 1891

# %%
lis=[]

# %%
for i in range(0,12):
    file=open("HPC_bash_"+str(i)+".sh",'w')
    file.write("#!/bin/bash\n")
    for j in range(0+i*160,160+i*160):
        file.write("wget "+final[j]+"\n")
    file.close()
    executer.write("chmod +x "+"HPC_bash_"+str(i)+".sh"+"\n")
    lis.append("HPC_bash_"+str(i)+".sh")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[198], line 5
#       3 file.write("#!/bin/bash\n")
#       4 for j in range(0+i*160,160+i*160):
# ----> 5     file.write("wget "+final[j]+"\n")
#       6 file.close()
#       7 executer.write("chmod +x "+"HPC_bash_"+str(i)+".sh"+"\n")
#
# IndexError: list index out of range

# %%
lis
# Out:
# ['HPC_bash_0.sh',
#  'HPC_bash_1.sh',
#  'HPC_bash_2.sh',
#  'HPC_bash_3.sh',
#  'HPC_bash_4.sh',
#  'HPC_bash_5.sh',
#  'HPC_bash_6.sh',
#  'HPC_bash_7.sh',
#  'HPC_bash_8.sh',
#  'HPC_bash_9.sh',
#  'HPC_bash_10.sh']

# %%
lis.append('HPC_bash_11.sh')

# %%
file=open("Uploader.sh",'w')
for i in lis[:]:
    file.write( "scp -P 22 "+i+" b21082@10.8.1.19:/wd/users/b21082/downloads" +"\n")
file.write( "scp -P 22 "+"executer.sh"+" b21082@10.8.1.19:/wd/users/b21082/downloads" +"\n")
file.write( "scp -P 22 "+"subp.py"+" b21082@10.8.1.19:/wd/users/b21082/downloads" +"\n")
file.close()

# %%
executer.close()

# %%
print(lis)
# Out:
# ['HPC_bash_0.sh', 'HPC_bash_1.sh', 'HPC_bash_2.sh', 'HPC_bash_3.sh', 'HPC_bash_4.sh', 'HPC_bash_5.sh', 'HPC_bash_6.sh', 'HPC_bash_7.sh', 'HPC_bash_8.sh', 'HPC_bash_9.sh', 'HPC_bash_10.sh', 'HPC_bash_11.sh']

# %%
file=open('deleter.sh','w')
file.write("#!/bin/bash\n")
# Out:
# 12

# %%
for i in range(1,852):
    file.write('rm HPC_bash_'+str(i)+'.sh'+'\n')

# %%
file.close()
