# %%
from selenium import webdriver
import time
import pyautogui as auto
from time import sleep

options = webdriver.ChromeOptions() ;
#THis is the selenium code for downloading files
prefs = {"download.default_directory" : "/Users/adityaruhela/Documents/Inter\ IIT"};
options.add_experimental_option("prefs",prefs);
list=['Put the list of the files to be downloaded here']
driver = webdriver.Chrome(executable_path='./chromedriver',chrome_options=options);


try:

    driver.get(list[0])
    downloadcsv= driver.find_element_by_css_selector('.icon-csv');

    gotit= driver.find_element_by_id('accept-cookie-notification');

    gotit.click();    

    downloadcsv.click();

    time.sleep(5)

    driver.close()

except: 
     sleep(7) #Don't change it
     #Within these 7 seconds, enter you username and password on PRADAN website
     
for i in range
#Yahan se loop laga sakte ho strings ka having download links
try:

    driver.get('https://pradan.issdc.gov.in/ch2/protected/downloadData/POST_OD/isda_archive/ch2_bundle/cho_bundle/nop/tmc_collection/data/derived/20210518/ch2_tmc_ndn_20210518T1656115474_d_oth_d18.zip?tmc2');

    downloadcsv= driver.find_element_by_css_selector('.icon-csv');

    gotit= driver.find_element_by_id('accept-cookie-notification');

    gotit.click();    

    downloadcsv.click();

    time.sleep(5)

    driver.close()

except:
     sleep(1)
try:

    driver.get('https://pradan.issdc.gov.in/ch2/protected/downloadData/POST_OD/isda_archive/ch2_bundle/cho_bundle/nop/tmc_collection/data/derived/20210518/ch2_tmc_ndn_20210518T1656115474_d_oth_d18.zip?tmc2');

    downloadcsv= driver.find_element_by_css_selector('.icon-csv');

    gotit= driver.find_element_by_id('accept-cookie-notification');

    gotit.click();    

    downloadcsv.click();

    time.sleep(5)

    driver.close()

except:
     sleep(1)
try:

    driver.get('https://pradan.issdc.gov.in/ch2/protected/downloadData/POST_OD/isda_archive/ch2_bundle/cho_bundle/nop/tmc_collection/data/derived/20210518/ch2_tmc_ndn_20210518T1656115474_d_oth_d18.zip?tmc2');

    downloadcsv= driver.find_element_by_css_selector('.icon-csv');

    gotit= driver.find_element_by_id('accept-cookie-notification');

    gotit.click();    

    downloadcsv.click();

    time.sleep(5)

    driver.close()

except:
     sleep(1)
